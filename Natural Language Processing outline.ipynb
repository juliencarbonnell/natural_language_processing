# %%
# import what is needed
import numpy as np 
import nltk 
import os 
import nltk.corpus

# %%
#missing package
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/juliencarbonnell/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#missing package
import nltk.probability

# %%
#missing package
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/juliencarbonnell/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#missing package
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/juliencarbonnell/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#missing package
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/juliencarbonnell/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.
# True

# %%
#missing package
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /Users/juliencarbonnell/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# True

# %%
# sample text for test
text = "Development Director \
ALS Therapy Development Institute has an immediate opening for Development Directors. Reporting directly to the Senior Development Director, the Development Director at ALS TDI is a senior fundraising position working to identifying potential prospects and cultivating solicitation strategies and in closing asks with donors including individuals and corporations by building networks via events, generating awareness of ALS TDI; outreach including attending and speaking at events as well as personally cultivates relationships with patients, prospects and donors. This position will be responsible for generating and managing a portfolio of at least two million to five million dollars per year. This position will be located in Atlanta, GA.\
Requirements:\
Bachelor's Degree requiredMinimum 6-8 years' experience in fundraising and business developmentSuccessful track recording in fundraising with major donors or scientific sales preferredDemonstrated ability to work independently and make progress on several prospects/projects at the same time.Excellent English oral, written and presentation skillsStrong leadership and management skills, as well as the ability to forge strong interpersonal relationshipsAbility to travelExcellent computer skills including use of word processing, spreadsheet, database, presentation and prospect management software operating off a PC-based system including Salesforce.\
About ALS Therapy Development Institute (ALS.net)\
The ALS Therapy Development Institute (ALS.net) and its scientists actively discover and develop treatments for ALS. ALS.net is the world's first and largest nonprofit biotech focused 100% on ALS research. Led by ALS patients and their families, the charity understands the urgent need to slow and stop this horrible disease. ALS.net, based in Cambridge, MA, has served as one of the leaders in sharing data and information with academic and ALS research organizations, patients and their families. For more information, visit www.als.net.\
To Apply\
Please apply at https://als.applicantpro.com. Please include a cover letter, salary requirements and resume. No phone calls please.\
ALS TDI is an equal opportunity employer."

text
# Out:
# "Development Director ALS Therapy Development Institute has an immediate opening for Development Directors. Reporting directly to the Senior Development Director, the Development Director at ALS TDI is a senior fundraising position working to identifying potential prospects and cultivating solicitation strategies and in closing asks with donors including individuals and corporations by building networks via events, generating awareness of ALS TDI; outreach including attending and speaking at events as well as personally cultivates relationships with patients, prospects and donors. This position will be responsible for generating and managing a portfolio of at least two million to five million dollars per year. This position will be located in Atlanta, GA.Requirements:Bachelor's Degree requiredMinimum 6-8 years' experience in fundraising and business developmentSuccessful track recording in fundraising with major donors or scientific sales preferredDemonstrated ability to work independently and make progress on several prospects/projects at the same time.Excellent English oral, written and presentation skillsStrong leadership and management skills, as well as the ability to forge strong interpersonal relationshipsAbility to travelExcellent computer skills including use of word processing, spreadsheet, database, presentation and prospect management software operating off a PC-based system including Salesforce.About ALS Therapy Development Institute (ALS.net)The ALS Therapy Development Institute (ALS.net) and its scientists actively discover and develop treatments for ALS. ALS.net is the world's first and largest nonprofit biotech focused 100% on ALS research. Led by ALS patients and their families, the charity understands the urgent need to slow and stop this horrible disease. ALS.net, based in Cambridge, MA, has served as one of the leaders in sharing data and information with academic and ALS research organizations, patients and their families. For more information, visit www.als.net.To ApplyPlease apply at https://als.applicantpro.com. Please include a cover letter, salary requirements and resume. No phone calls please.ALS TDI is an equal opportunity employer."

# %%
# importing word_tokenize from nltk
from nltk.tokenize import word_tokenize

# %%
# tokenise the text means cutting it into words
token = word_tokenize(text)
token
# Out:
# ['Development',
#  'Director',
#  'ALS',
#  'Therapy',
#  'Development',
#  'Institute',
#  'has',
#  'an',
#  'immediate',
#  'opening',
#  'for',
#  'Development',
#  'Directors',
#  '.',
#  'Reporting',
#  'directly',
#  'to',
#  'the',
#  'Senior',
#  'Development',
#  'Director',
#  ',',
#  'the',
#  'Development',
#  'Director',
#  'at',
#  'ALS',
#  'TDI',
#  'is',
#  'a',
#  'senior',
#  'fundraising',
#  'position',
#  'working',
#  'to',
#  'identifying',
#  'potential',
#  'prospects',
#  'and',
#  'cultivating',
#  'solicitation',
#  'strategies',
#  'and',
#  'in',
#  'closing',
#  'asks',
#  'with',
#  'donors',
#  'including',
#  'individuals',
#  'and',
#  'corporations',
#  'by',
#  'building',
#  'networks',
#  'via',
#  'events',
#  ',',
#  'generating',
#  'awareness',
#  'of',
#  'ALS',
#  'TDI',
#  ';',
#  'outreach',
#  'including',
#  'attending',
#  'and',
#  'speaking',
#  'at',
#  'events',
#  'as',
#  'well',
#  'as',
#  'personally',
#  'cultivates',
#  'relationships',
#  'with',
#  'patients',
#  ',',
#  'prospects',
#  'and',
#  'donors',
#  '.',
#  'This',
#  'position',
#  'will',
#  'be',
#  'responsible',
#  'for',
#  'generating',
#  'and',
#  'managing',
#  'a',
#  'portfolio',
#  'of',
#  'at',
#  'least',
#  'two',
#  'million',
#  'to',
#  'five',
#  'million',
#  'dollars',
#  'per',
#  'year',
#  '.',
#  'This',
#  'position',
#  'will',
#  'be',
#  'located',
#  'in',
#  'Atlanta',
#  ',',
#  'GA.Requirements',
#  ':',
#  'Bachelor',
#  "'s",
#  'Degree',
#  'requiredMinimum',
#  '6-8',
#  'years',
#  "'",
#  'experience',
#  'in',
#  'fundraising',
#  'and',
#  'business',
#  'developmentSuccessful',
#  'track',
#  'recording',
#  'in',
#  'fundraising',
#  'with',
#  'major',
#  'donors',
#  'or',
#  'scientific',
#  'sales',
#  'preferredDemonstrated',
#  'ability',
#  'to',
#  'work',
#  'independently',
#  'and',
#  'make',
#  'progress',
#  'on',
#  'several',
#  'prospects/projects',
#  'at',
#  'the',
#  'same',
#  'time.Excellent',
#  'English',
#  'oral',
#  ',',
#  'written',
#  'and',
#  'presentation',
#  'skillsStrong',
#  'leadership',
#  'and',
#  'management',
#  'skills',
#  ',',
#  'as',
#  'well',
#  'as',
#  'the',
#  'ability',
#  'to',
#  'forge',
#  'strong',
#  'interpersonal',
#  'relationshipsAbility',
#  'to',
#  'travelExcellent',
#  'computer',
#  'skills',
#  'including',
#  'use',
#  'of',
#  'word',
#  'processing',
#  ',',
#  'spreadsheet',
#  ',',
#  'database',
#  ',',
#  'presentation',
#  'and',
#  'prospect',
#  'management',
#  'software',
#  'operating',
#  'off',
#  'a',
#  'PC-based',
#  'system',
#  'including',
#  'Salesforce.About',
#  'ALS',
#  'Therapy',
#  'Development',
#  'Institute',
#  '(',
#  'ALS.net',
#  ')',
#  'The',
#  'ALS',
#  'Therapy',
#  'Development',
#  'Institute',
#  '(',
#  'ALS.net',
#  ')',
#  'and',
#  'its',
#  'scientists',
#  'actively',
#  'discover',
#  'and',
#  'develop',
#  'treatments',
#  'for',
#  'ALS',
#  '.',
#  'ALS.net',
#  'is',
#  'the',
#  'world',
#  "'s",
#  'first',
#  'and',
#  'largest',
#  'nonprofit',
#  'biotech',
#  'focused',
#  '100',
#  '%',
#  'on',
#  'ALS',
#  'research',
#  '.',
#  'Led',
#  'by',
#  'ALS',
#  'patients',
#  'and',
#  'their',
#  'families',
#  ',',
#  'the',
#  'charity',
#  'understands',
#  'the',
#  'urgent',
#  'need',
#  'to',
#  'slow',
#  'and',
#  'stop',
#  'this',
#  'horrible',
#  'disease',
#  '.',
#  'ALS.net',
#  ',',
#  'based',
#  'in',
#  'Cambridge',
#  ',',
#  'MA',
#  ',',
#  'has',
#  'served',
#  'as',
#  'one',
#  'of',
#  'the',
#  'leaders',
#  'in',
#  'sharing',
#  'data',
#  'and',
#  'information',
#  'with',
#  'academic',
#  'and',
#  'ALS',
#  'research',
#  'organizations',
#  ',',
#  'patients',
#  'and',
#  'their',
#  'families',
#  '.',
#  'For',
#  'more',
#  'information',
#  ',',
#  'visit',
#  'www.als.net.To',
#  'ApplyPlease',
#  'apply',
#  'at',
#  'https',
#  ':',
#  '//als.applicantpro.com',
#  '.',
#  'Please',
#  'include',
#  'a',
#  'cover',
#  'letter',
#  ',',
#  'salary',
#  'requirements',
#  'and',
#  'resume',
#  '.',
#  'No',
#  'phone',
#  'calls',
#  'please.ALS',
#  'TDI',
#  'is',
#  'an',
#  'equal',
#  'opportunity',
#  'employer',
#  '.']

# %%
# finding the frequency distinct in the tokens
# Importing FreqDist library from nltk and passing token into 
from nltk.probability import FreqDist
fdist = FreqDist(token)
fdist
# Out:
# FreqDist({'and': 20, ',': 16, '.': 10, 'ALS': 9, 'the': 8, 'Development': 7, 'to': 7, 'in': 6, 'at': 5, 'as': 5, ...})

# %%
# To find the frequency of top 10 words
fdist1 = fdist.most_common(10)
fdist1
# Out:
# [('and', 20),
#  (',', 16),
#  ('.', 10),
#  ('ALS', 9),
#  ('the', 8),
#  ('Development', 7),
#  ('to', 7),
#  ('in', 6),
#  ('at', 5),
#  ('as', 5)]

# %%
#stemming consists in grouping words by their common root (e.g "waiting", "waited", "waits" = "wait" )
#we will compare the results from Porterstemmer and those from LancasterStemmer

#importing Porterstemmer
from nltk.stem import PorterStemmer
pst = PorterStemmer()
pst.stem('Development')
# Out:
# 'develop'

# %%
# Checking for the list of words
for word in token :
   print(word+ ":" +pst.stem(word))
# Out:
# Development:develop
# Director:director
# ALS:al
# Therapy:therapi
# Development:develop
# Institute:institut
# has:ha
# an:an
# immediate:immedi
# opening:open
# for:for
# Development:develop
# Directors:director
# .:.
# Reporting:report
# directly:directli
# to:to
# the:the
# Senior:senior
# Development:develop
# Director:director
# ,:,
# the:the
# Development:develop
# Director:director
# at:at
# ALS:al
# TDI:tdi
# is:is
# a:a
# senior:senior
# fundraising:fundrais
# position:posit
# working:work
# to:to
# identifying:identifi
# potential:potenti
# prospects:prospect
# and:and
# cultivating:cultiv
# solicitation:solicit
# strategies:strategi
# and:and
# in:in
# closing:close
# asks:ask
# with:with
# donors:donor
# including:includ
# individuals:individu
# and:and
# corporations:corpor
# by:by
# building:build
# networks:network
# via:via
# events:event
# ,:,
# generating:gener
# awareness:awar
# of:of
# ALS:al
# TDI:tdi
# ;:;
# outreach:outreach
# including:includ
# attending:attend
# and:and
# speaking:speak
# at:at
# events:event
# as:as
# well:well
# as:as
# personally:person
# cultivates:cultiv
# relationships:relationship
# with:with
# patients:patient
# ,:,
# prospects:prospect
# and:and
# donors:donor
# .:.
# This:thi
# position:posit
# will:will
# be:be
# responsible:respons
# for:for
# generating:gener
# and:and
# managing:manag
# a:a
# portfolio:portfolio
# of:of
# at:at
# least:least
# two:two
# million:million
# to:to
# five:five
# million:million
# dollars:dollar
# per:per
# year:year
# .:.
# This:thi
# position:posit
# will:will
# be:be
# located:locat
# in:in
# Atlanta:atlanta
# ,:,
# GA.Requirements:ga.requir
# :::
# Bachelor:bachelor
# 's:'s
# Degree:degre
# requiredMinimum:requiredminimum
# 6-8:6-8
# years:year
# ':'
# experience:experi
# in:in
# fundraising:fundrais
# and:and
# business:busi
# developmentSuccessful:developmentsuccess
# track:track
# recording:record
# in:in
# fundraising:fundrais
# with:with
# major:major
# donors:donor
# or:or
# scientific:scientif
# sales:sale
# preferredDemonstrated:preferreddemonstr
# ability:abil
# to:to
# work:work
# independently:independ
# and:and
# make:make
# progress:progress
# on:on
# several:sever
# prospects/projects:prospects/project
# at:at
# the:the
# same:same
# time.Excellent:time.excel
# English:english
# oral:oral
# ,:,
# written:written
# and:and
# presentation:present
# skillsStrong:skillsstrong
# leadership:leadership
# and:and
# management:manag
# skills:skill
# ,:,
# as:as
# well:well
# as:as
# the:the
# ability:abil
# to:to
# forge:forg
# strong:strong
# interpersonal:interperson
# relationshipsAbility:relationships
# to:to
# travelExcellent:travelexcel
# computer:comput
# skills:skill
# including:includ
# use:use
# of:of
# word:word
# processing:process
# ,:,
# spreadsheet:spreadsheet
# ,:,
# database:databas
# ,:,
# presentation:present
# and:and
# prospect:prospect
# management:manag
# software:softwar
# operating:oper
# off:off
# a:a
# PC-based:pc-base
# system:system
# including:includ
# Salesforce.About:salesforce.about
# ALS:al
# Therapy:therapi
# Development:develop
# Institute:institut
# (:(
# ALS.net:als.net
# ):)
# The:the
# ALS:al
# Therapy:therapi
# Development:develop
# Institute:institut
# (:(
# ALS.net:als.net
# ):)
# and:and
# its:it
# scientists:scientist
# actively:activ
# discover:discov
# and:and
# develop:develop
# treatments:treatment
# for:for
# ALS:al
# .:.
# ALS.net:als.net
# is:is
# the:the
# world:world
# 's:'s
# first:first
# and:and
# largest:largest
# nonprofit:nonprofit
# biotech:biotech
# focused:focus
# 100:100
# %:%
# on:on
# ALS:al
# research:research
# .:.
# Led:led
# by:by
# ALS:al
# patients:patient
# and:and
# their:their
# families:famili
# ,:,
# the:the
# charity:chariti
# understands:understand
# the:the
# urgent:urgent
# need:need
# to:to
# slow:slow
# and:and
# stop:stop
# this:thi
# horrible:horribl
# disease:diseas
# .:.
# ALS.net:als.net
# ,:,
# based:base
# in:in
# Cambridge:cambridg
# ,:,
# MA:MA
# ,:,
# has:ha
# served:serv
# as:as
# one:one
# of:of
# the:the
# leaders:leader
# in:in
# sharing:share
# data:data
# and:and
# information:inform
# with:with
# academic:academ
# and:and
# ALS:al
# research:research
# organizations:organ
# ,:,
# patients:patient
# and:and
# their:their
# families:famili
# .:.
# For:for
# more:more
# information:inform
# ,:,
# visit:visit
# www.als.net.To:www.als.net.to
# ApplyPlease:applypleas
# apply:appli
# at:at
# https:http
# :::
# //als.applicantpro.com://als.applicantpro.com
# .:.
# Please:pleas
# include:includ
# a:a
# cover:cover
# letter:letter
# ,:,
# salary:salari
# requirements:requir
# and:and
# resume:resum
# .:.
# No:No
# phone:phone
# calls:call
# please.ALS:please.
# TDI:tdi
# is:is
# an:an
# equal:equal
# opportunity:opportun
# employer:employ
# .:.

# %%
# Importing LancasterStemmer from nltk
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
for word in token :
 print(word+ ":" +lst.stem(word))
# Out:
# Development:develop
# Director:direct
# ALS:al
# Therapy:therapy
# Development:develop
# Institute:institut
# has:has
# an:an
# immediate:immedy
# opening:op
# for:for
# Development:develop
# Directors:direct
# .:.
# Reporting:report
# directly:direct
# to:to
# the:the
# Senior:seny
# Development:develop
# Director:direct
# ,:,
# the:the
# Development:develop
# Director:direct
# at:at
# ALS:al
# TDI:tdi
# is:is
# a:a
# senior:seny
# fundraising:fundra
# position:posit
# working:work
# to:to
# identifying:ident
# potential:pot
# prospects:prospect
# and:and
# cultivating:cult
# solicitation:solicit
# strategies:strategies
# and:and
# in:in
# closing:clos
# asks:ask
# with:with
# donors:don
# including:includ
# individuals:individ
# and:and
# corporations:corp
# by:by
# building:build
# networks:network
# via:via
# events:ev
# ,:,
# generating:gen
# awareness:aw
# of:of
# ALS:al
# TDI:tdi
# ;:;
# outreach:outreach
# including:includ
# attending:attend
# and:and
# speaking:speak
# at:at
# events:ev
# as:as
# well:wel
# as:as
# personally:person
# cultivates:cult
# relationships:rel
# with:with
# patients:paty
# ,:,
# prospects:prospect
# and:and
# donors:don
# .:.
# This:thi
# position:posit
# will:wil
# be:be
# responsible:respons
# for:for
# generating:gen
# and:and
# managing:man
# a:a
# portfolio:portfolio
# of:of
# at:at
# least:least
# two:two
# million:mil
# to:to
# five:fiv
# million:mil
# dollars:doll
# per:per
# year:year
# .:.
# This:thi
# position:posit
# will:wil
# be:be
# located:loc
# in:in
# Atlanta:atlant
# ,:,
# GA.Requirements:ga.requirements
# :::
# Bachelor:bachel
# 's:'s
# Degree:degr
# requiredMinimum:requiredminim
# 6-8:6-8
# years:year
# ':'
# experience:expery
# in:in
# fundraising:fundra
# and:and
# business:busy
# developmentSuccessful:developmentsuccess
# track:track
# recording:record
# in:in
# fundraising:fundra
# with:with
# major:maj
# donors:don
# or:or
# scientific:sci
# sales:sal
# preferredDemonstrated:preferreddemonst
# ability:abl
# to:to
# work:work
# independently:independ
# and:and
# make:mak
# progress:progress
# on:on
# several:sev
# prospects/projects:prospects/project
# at:at
# the:the
# same:sam
# time.Excellent:time.excellent
# English:engl
# oral:or
# ,:,
# written:writ
# and:and
# presentation:pres
# skillsStrong:skillsstrong
# leadership:lead
# and:and
# management:man
# skills:skil
# ,:,
# as:as
# well:wel
# as:as
# the:the
# ability:abl
# to:to
# forge:forg
# strong:strong
# interpersonal:interperson
# relationshipsAbility:relationships
# to:to
# travelExcellent:travelexcel
# computer:comput
# skills:skil
# including:includ
# use:us
# of:of
# word:word
# processing:process
# ,:,
# spreadsheet:spreadsheet
# ,:,
# database:databas
# ,:,
# presentation:pres
# and:and
# prospect:prospect
# management:man
# software:softw
# operating:op
# off:off
# a:a
# PC-based:pc-based
# system:system
# including:includ
# Salesforce.About:salesforce.about
# ALS:al
# Therapy:therapy
# Development:develop
# Institute:institut
# (:(
# ALS.net:als.net
# ):)
# The:the
# ALS:al
# Therapy:therapy
# Development:develop
# Institute:institut
# (:(
# ALS.net:als.net
# ):)
# and:and
# its:it
# scientists:sci
# actively:act
# discover:discov
# and:and
# develop:develop
# treatments:tre
# for:for
# ALS:al
# .:.
# ALS.net:als.net
# is:is
# the:the
# world:world
# 's:'s
# first:first
# and:and
# largest:largest
# nonprofit:nonprofit
# biotech:biotech
# focused:focus
# 100:100
# %:%
# on:on
# ALS:al
# research:research
# .:.
# Led:led
# by:by
# ALS:al
# patients:paty
# and:and
# their:their
# families:famy
# ,:,
# the:the
# charity:char
# understands:understand
# the:the
# urgent:urg
# need:nee
# to:to
# slow:slow
# and:and
# stop:stop
# this:thi
# horrible:horr
# disease:diseas
# .:.
# ALS.net:als.net
# ,:,
# based:bas
# in:in
# Cambridge:cambridg
# ,:,
# MA:ma
# ,:,
# has:has
# served:serv
# as:as
# one:on
# of:of
# the:the
# leaders:lead
# in:in
# sharing:shar
# data:dat
# and:and
# information:inform
# with:with
# academic:academ
# and:and
# ALS:al
# research:research
# organizations:org
# ,:,
# patients:paty
# and:and
# their:their
# families:famy
# .:.
# For:for
# more:mor
# information:inform
# ,:,
# visit:visit
# www.als.net.To:www.als.net.to
# ApplyPlease:applypleas
# apply:apply
# at:at
# https:https
# :::
# //als.applicantpro.com://als.applicantpro.com
# .:.
# Please:pleas
# include:includ
# a:a
# cover:cov
# letter:let
# ,:,
# salary:sal
# requirements:requir
# and:and
# resume:resum
# .:.
# No:no
# phone:phon
# calls:cal
# please.ALS:please.als
# TDI:tdi
# is:is
# an:an
# equal:eq
# opportunity:opportun
# employer:employ
# .:.

# %%
# “Stop words” are the most common words in a language like “the”, “a”, “at”, “for”, “above”, “on”, “is”, “all”. 
#These words do not provide any meaning and are usually removed from texts.
# importing stopwors from nltk library
from nltk import word_tokenize
from nltk.corpus import stopwords
a = set(stopwords.words('english'))
text1 = word_tokenize(text.lower()) #normalize text in lower character
print(text1);
# Out:
# ['development', 'director', 'als', 'therapy', 'development', 'institute', 'has', 'an', 'immediate', 'opening', 'for', 'development', 'directors', '.', 'reporting', 'directly', 'to', 'the', 'senior', 'development', 'director', ',', 'the', 'development', 'director', 'at', 'als', 'tdi', 'is', 'a', 'senior', 'fundraising', 'position', 'working', 'to', 'identifying', 'potential', 'prospects', 'and', 'cultivating', 'solicitation', 'strategies', 'and', 'in', 'closing', 'asks', 'with', 'donors', 'including', 'individuals', 'and', 'corporations', 'by', 'building', 'networks', 'via', 'events', ',', 'generating', 'awareness', 'of', 'als', 'tdi', ';', 'outreach', 'including', 'attending', 'and', 'speaking', 'at', 'events', 'as', 'well', 'as', 'personally', 'cultivates', 'relationships', 'with', 'patients', ',', 'prospects', 'and', 'donors', '.', 'this', 'position', 'will', 'be', 'responsible', 'for', 'generating', 'and', 'managing', 'a', 'portfolio', 'of', 'at', 'least', 'two', 'million', 'to', 'five', 'million', 'dollars', 'per', 'year', '.', 'this', 'position', 'will', 'be', 'located', 'in', 'atlanta', ',', 'ga.requirements', ':', 'bachelor', "'s", 'degree', 'requiredminimum', '6-8', 'years', "'", 'experience', 'in', 'fundraising', 'and', 'business', 'developmentsuccessful', 'track', 'recording', 'in', 'fundraising', 'with', 'major', 'donors', 'or', 'scientific', 'sales', 'preferreddemonstrated', 'ability', 'to', 'work', 'independently', 'and', 'make', 'progress', 'on', 'several', 'prospects/projects', 'at', 'the', 'same', 'time.excellent', 'english', 'oral', ',', 'written', 'and', 'presentation', 'skillsstrong', 'leadership', 'and', 'management', 'skills', ',', 'as', 'well', 'as', 'the', 'ability', 'to', 'forge', 'strong', 'interpersonal', 'relationshipsability', 'to', 'travelexcellent', 'computer', 'skills', 'including', 'use', 'of', 'word', 'processing', ',', 'spreadsheet', ',', 'database', ',', 'presentation', 'and', 'prospect', 'management', 'software', 'operating', 'off', 'a', 'pc-based', 'system', 'including', 'salesforce.about', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'the', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'and', 'its', 'scientists', 'actively', 'discover', 'and', 'develop', 'treatments', 'for', 'als', '.', 'als.net', 'is', 'the', 'world', "'s", 'first', 'and', 'largest', 'nonprofit', 'biotech', 'focused', '100', '%', 'on', 'als', 'research', '.', 'led', 'by', 'als', 'patients', 'and', 'their', 'families', ',', 'the', 'charity', 'understands', 'the', 'urgent', 'need', 'to', 'slow', 'and', 'stop', 'this', 'horrible', 'disease', '.', 'als.net', ',', 'based', 'in', 'cambridge', ',', 'ma', ',', 'has', 'served', 'as', 'one', 'of', 'the', 'leaders', 'in', 'sharing', 'data', 'and', 'information', 'with', 'academic', 'and', 'als', 'research', 'organizations', ',', 'patients', 'and', 'their', 'families', '.', 'for', 'more', 'information', ',', 'visit', 'www.als.net.to', 'applyplease', 'apply', 'at', 'https', ':', '//als.applicantpro.com', '.', 'please', 'include', 'a', 'cover', 'letter', ',', 'salary', 'requirements', 'and', 'resume', '.', 'no', 'phone', 'calls', 'please.als', 'tdi', 'is', 'an', 'equal', 'opportunity', 'employer', '.']
# ['development', 'director', 'als', 'therapy', 'development', 'institute', 'immediate', 'opening', 'development', 'directors', '.', 'reporting', 'directly', 'senior', 'development', 'director', ',', 'development', 'director', 'als', 'tdi', 'senior', 'fundraising', 'position', 'working', 'identifying', 'potential', 'prospects', 'cultivating', 'solicitation', 'strategies', 'closing', 'asks', 'donors', 'including', 'individuals', 'corporations', 'building', 'networks', 'via', 'events', ',', 'generating', 'awareness', 'als', 'tdi', ';', 'outreach', 'including', 'attending', 'speaking', 'events', 'well', 'personally', 'cultivates', 'relationships', 'patients', ',', 'prospects', 'donors', '.', 'position', 'responsible', 'generating', 'managing', 'portfolio', 'least', 'two', 'million', 'five', 'million', 'dollars', 'per', 'year', '.', 'position', 'located', 'atlanta', ',', 'ga.requirements', ':', 'bachelor', "'s", 'degree', 'requiredminimum', '6-8', 'years', "'", 'experience', 'fundraising', 'business', 'developmentsuccessful', 'track', 'recording', 'fundraising', 'major', 'donors', 'scientific', 'sales', 'preferreddemonstrated', 'ability', 'work', 'independently', 'make', 'progress', 'several', 'prospects/projects', 'time.excellent', 'english', 'oral', ',', 'written', 'presentation', 'skillsstrong', 'leadership', 'management', 'skills', ',', 'well', 'ability', 'forge', 'strong', 'interpersonal', 'relationshipsability', 'travelexcellent', 'computer', 'skills', 'including', 'use', 'word', 'processing', ',', 'spreadsheet', ',', 'database', ',', 'presentation', 'prospect', 'management', 'software', 'operating', 'pc-based', 'system', 'including', 'salesforce.about', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'scientists', 'actively', 'discover', 'develop', 'treatments', 'als', '.', 'als.net', 'world', "'s", 'first', 'largest', 'nonprofit', 'biotech', 'focused', '100', '%', 'als', 'research', '.', 'led', 'als', 'patients', 'families', ',', 'charity', 'understands', 'urgent', 'need', 'slow', 'stop', 'horrible', 'disease', '.', 'als.net', ',', 'based', 'cambridge', ',', ',', 'served', 'one', 'leaders', 'sharing', 'data', 'information', 'academic', 'als', 'research', 'organizations', ',', 'patients', 'families', '.', 'information', ',', 'visit', 'www.als.net.to', 'applyplease', 'apply', 'https', ':', '//als.applicantpro.com', '.', 'please', 'include', 'cover', 'letter', ',', 'salary', 'requirements', 'resume', '.', 'phone', 'calls', 'please.als', 'tdi', 'equal', 'opportunity', 'employer', '.']

# %%
#compare with stopwords result 
stopwords = [x for x in text1 if x not in a]
print(stopwords);
# Out:
# ['development', 'director', 'als', 'therapy', 'development', 'institute', 'immediate', 'opening', 'development', 'directors', '.', 'reporting', 'directly', 'senior', 'development', 'director', ',', 'development', 'director', 'als', 'tdi', 'senior', 'fundraising', 'position', 'working', 'identifying', 'potential', 'prospects', 'cultivating', 'solicitation', 'strategies', 'closing', 'asks', 'donors', 'including', 'individuals', 'corporations', 'building', 'networks', 'via', 'events', ',', 'generating', 'awareness', 'als', 'tdi', ';', 'outreach', 'including', 'attending', 'speaking', 'events', 'well', 'personally', 'cultivates', 'relationships', 'patients', ',', 'prospects', 'donors', '.', 'position', 'responsible', 'generating', 'managing', 'portfolio', 'least', 'two', 'million', 'five', 'million', 'dollars', 'per', 'year', '.', 'position', 'located', 'atlanta', ',', 'ga.requirements', ':', 'bachelor', "'s", 'degree', 'requiredminimum', '6-8', 'years', "'", 'experience', 'fundraising', 'business', 'developmentsuccessful', 'track', 'recording', 'fundraising', 'major', 'donors', 'scientific', 'sales', 'preferreddemonstrated', 'ability', 'work', 'independently', 'make', 'progress', 'several', 'prospects/projects', 'time.excellent', 'english', 'oral', ',', 'written', 'presentation', 'skillsstrong', 'leadership', 'management', 'skills', ',', 'well', 'ability', 'forge', 'strong', 'interpersonal', 'relationshipsability', 'travelexcellent', 'computer', 'skills', 'including', 'use', 'word', 'processing', ',', 'spreadsheet', ',', 'database', ',', 'presentation', 'prospect', 'management', 'software', 'operating', 'pc-based', 'system', 'including', 'salesforce.about', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'als', 'therapy', 'development', 'institute', '(', 'als.net', ')', 'scientists', 'actively', 'discover', 'develop', 'treatments', 'als', '.', 'als.net', 'world', "'s", 'first', 'largest', 'nonprofit', 'biotech', 'focused', '100', '%', 'als', 'research', '.', 'led', 'als', 'patients', 'families', ',', 'charity', 'understands', 'urgent', 'need', 'slow', 'stop', 'horrible', 'disease', '.', 'als.net', ',', 'based', 'cambridge', ',', ',', 'served', 'one', 'leaders', 'sharing', 'data', 'information', 'academic', 'als', 'research', 'organizations', ',', 'patients', 'families', '.', 'information', ',', 'visit', 'www.als.net.to', 'applyplease', 'apply', 'https', ':', '//als.applicantpro.com', '.', 'please', 'include', 'cover', 'letter', ',', 'salary', 'requirements', 'resume', '.', 'phone', 'calls', 'please.als', 'tdi', 'equal', 'opportunity', 'employer', '.']

# %%
# Part-of-speech tagging is used to assign parts of speech to each word of a given text (such as nouns, verbs, ...)
#based on its definition and its context.
for word in token:
    print(nltk.pos_tag([word]))
# Out:
# [('Development', 'NNP')]
# [('Director', 'NN')]
# [('ALS', 'NNS')]
# [('Therapy', 'NN')]
# [('Development', 'NNP')]
# [('Institute', 'NNP')]
# [('has', 'VBZ')]
# [('an', 'DT')]
# [('immediate', 'NN')]
# [('opening', 'NN')]
# [('for', 'IN')]
# [('Development', 'NNP')]
# [('Directors', 'NNS')]
# [('.', '.')]
# [('Reporting', 'VBG')]
# [('directly', 'RB')]
# [('to', 'TO')]
# [('the', 'DT')]
# [('Senior', 'JJ')]
# [('Development', 'NNP')]
# [('Director', 'NN')]
# [(',', ',')]
# [('the', 'DT')]
# [('Development', 'NNP')]
# [('Director', 'NN')]
# [('at', 'IN')]
# [('ALS', 'NNS')]
# [('TDI', 'NN')]
# [('is', 'VBZ')]
# [('a', 'DT')]
# [('senior', 'JJ')]
# [('fundraising', 'VBG')]
# [('position', 'NN')]
# [('working', 'VBG')]
# [('to', 'TO')]
# [('identifying', 'VBG')]
# [('potential', 'JJ')]
# [('prospects', 'NNS')]
# [('and', 'CC')]
# [('cultivating', 'VBG')]
# [('solicitation', 'NN')]
# [('strategies', 'NNS')]
# [('and', 'CC')]
# [('in', 'IN')]
# [('closing', 'NN')]
# [('asks', 'NNS')]
# [('with', 'IN')]
# [('donors', 'NNS')]
# [('including', 'VBG')]
# [('individuals', 'NNS')]
# [('and', 'CC')]
# [('corporations', 'NNS')]
# [('by', 'IN')]
# [('building', 'NN')]
# [('networks', 'NNS')]
# [('via', 'IN')]
# [('events', 'NNS')]
# [(',', ',')]
# [('generating', 'VBG')]
# [('awareness', 'NN')]
# [('of', 'IN')]
# [('ALS', 'NNS')]
# [('TDI', 'NN')]
# [(';', ':')]
# [('outreach', 'NN')]
# [('including', 'VBG')]
# [('attending', 'VBG')]
# [('and', 'CC')]
# [('speaking', 'VBG')]
# [('at', 'IN')]
# [('events', 'NNS')]
# [('as', 'IN')]
# [('well', 'RB')]
# [('as', 'IN')]
# [('personally', 'RB')]
# [('cultivates', 'NNS')]
# [('relationships', 'NNS')]
# [('with', 'IN')]
# [('patients', 'NNS')]
# [(',', ',')]
# [('prospects', 'NNS')]
# [('and', 'CC')]
# [('donors', 'NNS')]
# [('.', '.')]
# [('This', 'DT')]
# [('position', 'NN')]
# [('will', 'MD')]
# [('be', 'VB')]
# [('responsible', 'JJ')]
# [('for', 'IN')]
# [('generating', 'VBG')]
# [('and', 'CC')]
# [('managing', 'VBG')]
# [('a', 'DT')]
# [('portfolio', 'NN')]
# [('of', 'IN')]
# [('at', 'IN')]
# [('least', 'JJS')]
# [('two', 'CD')]
# [('million', 'CD')]
# [('to', 'TO')]
# [('five', 'CD')]
# [('million', 'CD')]
# [('dollars', 'NNS')]
# [('per', 'IN')]
# [('year', 'NN')]
# [('.', '.')]
# [('This', 'DT')]
# [('position', 'NN')]
# [('will', 'MD')]
# [('be', 'VB')]
# [('located', 'VBN')]
# [('in', 'IN')]
# [('Atlanta', 'NNP')]
# [(',', ',')]
# [('GA.Requirements', 'NNS')]
# [(':', ':')]
# [('Bachelor', 'NN')]
# [("'s", 'POS')]
# [('Degree', 'NN')]
# [('requiredMinimum', 'NN')]
# [('6-8', 'JJ')]
# [('years', 'NNS')]
# [("'", "''")]
# [('experience', 'NN')]
# [('in', 'IN')]
# [('fundraising', 'VBG')]
# [('and', 'CC')]
# [('business', 'NN')]
# [('developmentSuccessful', 'NN')]
# [('track', 'NN')]
# [('recording', 'VBG')]
# [('in', 'IN')]
# [('fundraising', 'VBG')]
# [('with', 'IN')]
# [('major', 'JJ')]
# [('donors', 'NNS')]
# [('or', 'CC')]
# [('scientific', 'JJ')]
# [('sales', 'NNS')]
# [('preferredDemonstrated', 'VBN')]
# [('ability', 'NN')]
# [('to', 'TO')]
# [('work', 'NN')]
# [('independently', 'RB')]
# [('and', 'CC')]
# [('make', 'VB')]
# [('progress', 'NN')]
# [('on', 'IN')]
# [('several', 'JJ')]
# [('prospects/projects', 'NNS')]
# [('at', 'IN')]
# [('the', 'DT')]
# [('same', 'JJ')]
# [('time.Excellent', 'NN')]
# [('English', 'JJ')]
# [('oral', 'JJ')]
# [(',', ',')]
# [('written', 'VBN')]
# [('and', 'CC')]
# [('presentation', 'NN')]
# [('skillsStrong', 'NN')]
# [('leadership', 'NN')]
# [('and', 'CC')]
# [('management', 'NN')]
# [('skills', 'NNS')]
# [(',', ',')]
# [('as', 'IN')]
# [('well', 'RB')]
# [('as', 'IN')]
# [('the', 'DT')]
# [('ability', 'NN')]
# [('to', 'TO')]
# [('forge', 'NN')]
# [('strong', 'JJ')]
# [('interpersonal', 'JJ')]
# [('relationshipsAbility', 'NN')]
# [('to', 'TO')]
# [('travelExcellent', 'NN')]
# [('computer', 'NN')]
# [('skills', 'NNS')]
# [('including', 'VBG')]
# [('use', 'NN')]
# [('of', 'IN')]
# [('word', 'NN')]
# [('processing', 'NN')]
# [(',', ',')]
# [('spreadsheet', 'NN')]
# [(',', ',')]
# [('database', 'NN')]
# [(',', ',')]
# [('presentation', 'NN')]
# [('and', 'CC')]
# [('prospect', 'NN')]
# [('management', 'NN')]
# [('software', 'NN')]
# [('operating', 'NN')]
# [('off', 'IN')]
# [('a', 'DT')]
# [('PC-based', 'JJ')]
# [('system', 'NN')]
# [('including', 'VBG')]
# [('Salesforce.About', 'NN')]
# [('ALS', 'NNS')]
# [('Therapy', 'NN')]
# [('Development', 'NNP')]
# [('Institute', 'NNP')]
# [('(', '(')]
# [('ALS.net', 'NN')]
# [(')', ')')]
# [('The', 'DT')]
# [('ALS', 'NNS')]
# [('Therapy', 'NN')]
# [('Development', 'NNP')]
# [('Institute', 'NNP')]
# [('(', '(')]
# [('ALS.net', 'NN')]
# [(')', ')')]
# [('and', 'CC')]
# [('its', 'PRP$')]
# [('scientists', 'NNS')]
# [('actively', 'RB')]
# [('discover', 'NN')]
# [('and', 'CC')]
# [('develop', 'VB')]
# [('treatments', 'NNS')]
# [('for', 'IN')]
# [('ALS', 'NNS')]
# [('.', '.')]
# [('ALS.net', 'NN')]
# [('is', 'VBZ')]
# [('the', 'DT')]
# [('world', 'NN')]
# [("'s", 'POS')]
# [('first', 'RB')]
# [('and', 'CC')]
# [('largest', 'JJS')]
# [('nonprofit', 'NN')]
# [('biotech', 'NN')]
# [('focused', 'VBN')]
# [('100', 'CD')]
# [('%', 'NN')]
# [('on', 'IN')]
# [('ALS', 'NNS')]
# [('research', 'NN')]
# [('.', '.')]
# [('Led', 'VB')]
# [('by', 'IN')]
# [('ALS', 'NNS')]
# [('patients', 'NNS')]
# [('and', 'CC')]
# [('their', 'PRP$')]
# [('families', 'NNS')]
# [(',', ',')]
# [('the', 'DT')]
# [('charity', 'NN')]
# [('understands', 'NNS')]
# [('the', 'DT')]
# [('urgent', 'NN')]
# [('need', 'NN')]
# [('to', 'TO')]
# [('slow', 'VB')]
# [('and', 'CC')]
# [('stop', 'NN')]
# [('this', 'DT')]
# [('horrible', 'JJ')]
# [('disease', 'NN')]
# [('.', '.')]
# [('ALS.net', 'NN')]
# [(',', ',')]
# [('based', 'VBN')]
# [('in', 'IN')]
# [('Cambridge', 'NN')]
# [(',', ',')]
# [('MA', 'NN')]
# [(',', ',')]
# [('has', 'VBZ')]
# [('served', 'VBD')]
# [('as', 'IN')]
# [('one', 'CD')]
# [('of', 'IN')]
# [('the', 'DT')]
# [('leaders', 'NNS')]
# [('in', 'IN')]
# [('sharing', 'VBG')]
# [('data', 'NNS')]
# [('and', 'CC')]
# [('information', 'NN')]
# [('with', 'IN')]
# [('academic', 'JJ')]
# [('and', 'CC')]
# [('ALS', 'NNS')]
# [('research', 'NN')]
# [('organizations', 'NNS')]
# [(',', ',')]
# [('patients', 'NNS')]
# [('and', 'CC')]
# [('their', 'PRP$')]
# [('families', 'NNS')]
# [('.', '.')]
# [('For', 'IN')]
# [('more', 'RBR')]
# [('information', 'NN')]
# [(',', ',')]
# [('visit', 'NN')]
# [('www.als.net.To', 'NN')]
# [('ApplyPlease', 'NN')]
# [('apply', 'VB')]
# [('at', 'IN')]
# [('https', 'NN')]
# [(':', ':')]
# [('//als.applicantpro.com', 'NN')]
# [('.', '.')]
# [('Please', 'VB')]
# [('include', 'NN')]
# [('a', 'DT')]
# [('cover', 'NN')]
# [('letter', 'NN')]
# [(',', ',')]
# [('salary', 'NN')]
# [('requirements', 'NNS')]
# [('and', 'CC')]
# [('resume', 'NN')]
# [('.', '.')]
# [('No', 'DT')]
# [('phone', 'NN')]
# [('calls', 'NNS')]
# [('please.ALS', 'NN')]
# [('TDI', 'NN')]
# [('is', 'VBZ')]
# [('an', 'DT')]
# [('equal', 'JJ')]
# [('opportunity', 'NN')]
# [('employer', 'NN')]
# [('.', '.')]

# %%
#Named entity recognition is the process of detecting person name, the location name, the company name, ...

#importing chunk library from nltk
from nltk import ne_chunk

# re-tokenize your text and POS Tagging before doing chunk
token = word_tokenize(text)
tags = nltk.pos_tag(token)
chunk = ne_chunk(tags)
chunk
# Out:
# Tree('S', [('Development', 'NNP'), ('Director', 'NNP'), ('ALS', 'NNP'), ('Therapy', 'NNP'), ('Development', 'NNP'), ('Institute', 'NNP'), ('has', 'VBZ'), ('an', 'DT'), ('immediate', 'JJ'), ('opening', 'NN'), ('for', 'IN'), Tree('ORGANIZATION', [('Development', 'NNP'), ('Directors', 'NNPS')]), ('.', '.'), ('Reporting', 'VBG'), ('directly', 'RB'), ('to', 'TO'), ('the', 'DT'), Tree('ORGANIZATION', [('Senior', 'NNP'), ('Development', 'NNP'), ('Director', 'NNP')]), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('Development', 'NNP')]), ('Director', 'NNP'), ('at', 'IN'), Tree('ORGANIZATION', [('ALS', 'NNP')]), ('TDI', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('senior', 'JJ'), ('fundraising', 'NN'), ('position', 'NN'), ('working', 'VBG'), ('to', 'TO'), ('identifying', 'VBG'), ('potential', 'JJ'), ('prospects', 'NNS'), ('and', 'CC'), ('cultivating', 'VBG'), ('solicitation', 'NN'), ('strategies', 'NNS'), ('and', 'CC'), ('in', 'IN'), ('closing', 'NN'), ('asks', 'NNS'), ('with', 'IN'), ('donors', 'NNS'), ('including', 'VBG'), ('individuals', 'NNS'), ('and', 'CC'), ('corporations', 'NNS'), ('by', 'IN'), ('building', 'VBG'), ('networks', 'NNS'), ('via', 'IN'), ('events', 'NNS'), (',', ','), ('generating', 'VBG'), ('awareness', 'NN'), ('of', 'IN'), Tree('ORGANIZATION', [('ALS', 'NNP')]), ('TDI', 'NNP'), (';', ':'), ('outreach', 'NN'), ('including', 'VBG'), ('attending', 'VBG'), ('and', 'CC'), ('speaking', 'VBG'), ('at', 'IN'), ('events', 'NNS'), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('personally', 'RB'), ('cultivates', 'VBZ'), ('relationships', 'NNS'), ('with', 'IN'), ('patients', 'NNS'), (',', ','), ('prospects', 'NNS'), ('and', 'CC'), ('donors', 'NNS'), ('.', '.'), ('This', 'DT'), ('position', 'NN'), ('will', 'MD'), ('be', 'VB'), ('responsible', 'JJ'), ('for', 'IN'), ('generating', 'VBG'), ('and', 'CC'), ('managing', 'VBG'), ('a', 'DT'), ('portfolio', 'NN'), ('of', 'IN'), ('at', 'IN'), ('least', 'JJS'), ('two', 'CD'), ('million', 'CD'), ('to', 'TO'), ('five', 'CD'), ('million', 'CD'), ('dollars', 'NNS'), ('per', 'IN'), ('year', 'NN'), ('.', '.'), ('This', 'DT'), ('position', 'NN'), ('will', 'MD'), ('be', 'VB'), ('located', 'VBN'), ('in', 'IN'), Tree('GPE', [('Atlanta', 'NNP')]), (',', ','), ('GA.Requirements', 'VBZ'), (':', ':'), Tree('PERSON', [('Bachelor', 'NNP')]), ("'s", 'POS'), Tree('ORGANIZATION', [('Degree', 'NNP')]), ('requiredMinimum', 'VBZ'), ('6-8', 'CD'), ('years', 'NNS'), ("'", 'POS'), ('experience', 'NN'), ('in', 'IN'), ('fundraising', 'NN'), ('and', 'CC'), ('business', 'NN'), Tree('ORGANIZATION', [('developmentSuccessful', 'JJ')]), ('track', 'NN'), ('recording', 'NN'), ('in', 'IN'), ('fundraising', 'VBG'), ('with', 'IN'), ('major', 'JJ'), ('donors', 'NNS'), ('or', 'CC'), ('scientific', 'JJ'), ('sales', 'NNS'), ('preferredDemonstrated', 'VBN'), ('ability', 'NN'), ('to', 'TO'), ('work', 'VB'), ('independently', 'RB'), ('and', 'CC'), ('make', 'VB'), ('progress', 'NN'), ('on', 'IN'), ('several', 'JJ'), ('prospects/projects', 'NNS'), ('at', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('time.Excellent', 'NN'), Tree('GPE', [('English', 'NNP')]), ('oral', 'NN'), (',', ','), ('written', 'VBN'), ('and', 'CC'), ('presentation', 'NN'), Tree('ORGANIZATION', [('skillsStrong', 'JJ')]), ('leadership', 'NN'), ('and', 'CC'), ('management', 'NN'), ('skills', 'NNS'), (',', ','), ('as', 'RB'), ('well', 'RB'), ('as', 'IN'), ('the', 'DT'), ('ability', 'NN'), ('to', 'TO'), ('forge', 'VB'), ('strong', 'JJ'), ('interpersonal', 'JJ'), ('relationshipsAbility', 'NN'), ('to', 'TO'), ('travelExcellent', 'VB'), ('computer', 'NN'), ('skills', 'NNS'), ('including', 'VBG'), ('use', 'NN'), ('of', 'IN'), ('word', 'NN'), ('processing', 'NN'), (',', ','), ('spreadsheet', 'NN'), (',', ','), ('database', 'NN'), (',', ','), ('presentation', 'NN'), ('and', 'CC'), ('prospect', 'JJ'), ('management', 'NN'), ('software', 'NN'), ('operating', 'VBG'), ('off', 'RP'), ('a', 'DT'), ('PC-based', 'JJ'), ('system', 'NN'), ('including', 'VBG'), ('Salesforce.About', 'NNP'), ('ALS', ...

# %%
#chunking means a grouping of words or tokens into chunks (=pieces of information)
reg = "NP: {<DT>?<JJ>*<NN>}"
a = nltk.RegexpParser(reg)
result = a.parse(tags)
print(result)
# Out:
# (S
#   Development/NNP
#   Director/NNP
#   ALS/NNP
#   Therapy/NNP
#   Development/NNP
#   Institute/NNP
#   has/VBZ
#   (NP an/DT immediate/JJ opening/NN)
#   for/IN
#   Development/NNP
#   Directors/NNPS
#   ./.
#   Reporting/VBG
#   directly/RB
#   to/TO
#   the/DT
#   Senior/NNP
#   Development/NNP
#   Director/NNP
#   ,/,
#   the/DT
#   Development/NNP
#   Director/NNP
#   at/IN
#   ALS/NNP
#   TDI/NNP
#   is/VBZ
#   (NP a/DT senior/JJ fundraising/NN)
#   (NP position/NN)
#   working/VBG
#   to/TO
#   identifying/VBG
#   potential/JJ
#   prospects/NNS
#   and/CC
#   cultivating/VBG
#   (NP solicitation/NN)
#   strategies/NNS
#   and/CC
#   in/IN
#   (NP closing/NN)
#   asks/NNS
#   with/IN
#   donors/NNS
#   including/VBG
#   individuals/NNS
#   and/CC
#   corporations/NNS
#   by/IN
#   building/VBG
#   networks/NNS
#   via/IN
#   events/NNS
#   ,/,
#   generating/VBG
#   (NP awareness/NN)
#   of/IN
#   ALS/NNP
#   TDI/NNP
#   ;/:
#   (NP outreach/NN)
#   including/VBG
#   attending/VBG
#   and/CC
#   speaking/VBG
#   at/IN
#   events/NNS
#   as/RB
#   well/RB
#   as/IN
#   personally/RB
#   cultivates/VBZ
#   relationships/NNS
#   with/IN
#   patients/NNS
#   ,/,
#   prospects/NNS
#   and/CC
#   donors/NNS
#   ./.
#   (NP This/DT position/NN)
#   will/MD
#   be/VB
#   responsible/JJ
#   for/IN
#   generating/VBG
#   and/CC
#   managing/VBG
#   (NP a/DT portfolio/NN)
#   of/IN
#   at/IN
#   least/JJS
#   two/CD
#   million/CD
#   to/TO
#   five/CD
#   million/CD
#   dollars/NNS
#   per/IN
#   (NP year/NN)
#   ./.
#   (NP This/DT position/NN)
#   will/MD
#   be/VB
#   located/VBN
#   in/IN
#   Atlanta/NNP
#   ,/,
#   GA.Requirements/VBZ
#   :/:
#   Bachelor/NNP
#   's/POS
#   Degree/NNP
#   requiredMinimum/VBZ
#   6-8/CD
#   years/NNS
#   '/POS
#   (NP experience/NN)
#   in/IN
#   (NP fundraising/NN)
#   and/CC
#   (NP business/NN)
#   (NP developmentSuccessful/JJ track/NN)
#   (NP recording/NN)
#   in/IN
#   fundraising/VBG
#   with/IN
#   major/JJ
#   donors/NNS
#   or/CC
#   scientific/JJ
#   sales/NNS
#   preferredDemonstrated/VBN
#   (NP ability/NN)
#   to/TO
#   work/VB
#   independently/RB
#   and/CC
#   make/VB
#   (NP progress/NN)
#   on/IN
#   several/JJ
#   prospects/projects/NNS
#   at/IN
#   (NP the/DT same/JJ time.Excellent/NN)
#   English/NNP
#   (NP oral/NN)
#   ,/,
#   written/VBN
#   and/CC
#   (NP presentation/NN)
#   (NP skillsStrong/JJ leadership/NN)
#   and/CC
#   (NP management/NN)
#   skills/NNS
#   ,/,
#   as/RB
#   well/RB
#   as/IN
#   (NP the/DT ability/NN)
#   to/TO
#   forge/VB
#   (NP strong/JJ interpersonal/JJ relationshipsAbility/NN)
#   to/TO
#   travelExcellent/VB
#   (NP computer/NN)
#   skills/NNS
#   including/VBG
#   (NP use/NN)
#   of/IN
#   (NP word/NN)
#   (NP processing/NN)
#   ,/,
#   (NP spreadsheet/NN)
#   ,/,
#   (NP database/NN)
#   ,/,
#   (NP presentation/NN)
#   and/CC
#   (NP prospect/JJ management/NN)
#   (NP software/NN)
#   operating/VBG
#   off/RP
#   (NP a/DT PC-based/JJ system/NN)
#   including/VBG
#   Salesforce.About/NNP
#   ALS/NNP
#   Therapy/NNP
#   Development/NNP
#   Institute/NNP
#   (/(
#   ALS.net/NNP
#   )/)
#   The/DT
#   ALS/NNP
#   Therapy/NNP
#   Development/NNP
#   Institute/NNP
#   (/(
#   ALS.net/NNP
#   )/)
#   and/CC
#   its/PRP$
#   scientists/NNS
#   actively/RB
#   discover/RB
#   and/CC
#   develop/VB
#   treatments/NNS
#   for/IN
#   ALS/NNP
#   ./.
#   ALS.net/NNP
#   is/VBZ
#   (NP the/DT world/NN)
#   's/POS
#   first/JJ
#   and/CC
#   largest/JJS
#   (NP nonprofit/JJ biotech/NN)
#   focused/VBD
#   100/CD
#   (NP %/NN)
#   on/IN
#   ALS/NNP
#   (NP research/NN)
#   ./.
#   Led/VBN
#   by/IN
#   ALS/NNP
#   patients/NNS
#   and/CC
#   their/PRP$
#   families/NNS
#   ,/,
#   (NP the/DT charity/NN)
#   understands/VBZ
#   (NP the/DT urgent/JJ need/NN)
#   to/TO
#   slow/VB
#   and/CC
#   stop/VB
#   (NP this/DT horrible/JJ disease/NN)
#   ./.
#   ALS.net/NNP
#   ,/,
#   based/VBN
#   in/IN
#   Cambridge/NNP
#   ,/,
#   MA/NNP
#   ,/,
#   has/VBZ
#   served/VBN
#   as/IN
#   one/CD
#   of/IN
#   the/DT
#   leaders/NNS
#   in/IN
#   sharing/VBG
#   data/NNS
#   and/CC
#   (NP information/NN)
#   with/IN
#   academic/JJ
#   and/CC
#   ALS/NNP
#   (NP research/NN)
#   organizations/NNS
#   ,/,
#   patients/NNS
#   and/CC
#   their/PRP$
#   families/NNS
#   ./.
#   For/IN
#   more/JJR
#   (NP information/NN)
#   ,/,
#   (NP visit/NN)
#   (NP www.als.net.To/NN)
#   ApplyPlease/NNP
#   (NP apply/NN)
#   at/IN
#   (NP https/NN)
#   :/:
#   (NP //als.applicantpro.com/NN)
#   ./.
#   Please/NNP
#   include/VBP
#   (NP a/DT cover/JJ letter/NN)
#   ,/,
#   salary/JJ
#   requirements/NNS
#   and/CC
#   resume/VB
#   ./.
#   (NP No/DT phone/NN)
#   calls/VBZ
#   please.ALS/JJ
#   TDI/NNP
#   is/VBZ
#   (NP an/DT equal/JJ opportunity/NN)
#   (NP employer/NN)
#   ./.)
